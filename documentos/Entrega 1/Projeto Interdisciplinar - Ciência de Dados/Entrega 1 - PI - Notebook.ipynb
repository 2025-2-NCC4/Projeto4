# %%
# Bloco 1: Imports e Configurações
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuração visual
plt.style.use("seaborn-v0_8")
sns.set_palette("pastel")
pd.set_option("display.max_columns", None)

# %%
# Bloco 2: Carregar os datasets
players = pd.read_csv("base_players.csv", sep=";")
lojas = pd.read_csv("lojas_valores.csv", sep=";")
transacoes = pd.read_csv("transacoes_cupons.csv", sep=";")
pedestres = pd.read_csv("pedestres_paulista.csv", sep=";")

# Mostrar dimensões
print("Players:", players.shape)
print("Lojas:", lojas.shape)
print("Transações:", transacoes.shape)
print("Pedestres:", pedestres.shape)
# Out:
# Players: (10000, 11)
# Lojas: (10000, 11)
# Transações: (100000, 12)
# Pedestres: (100000, 15)

# %%
# Bloco 3: Verificar qualidade dos dados

def qualidade_dados(df, nome):
    print(f"\nDataset: {nome}")
    print("Dimensões:", df.shape)
    print("\nTipos de dados:")
    print(df.dtypes)
    print("\nValores ausentes:")
    print(df.isnull().sum())
    print("\nDuplicados:", df.duplicated().sum())
    print("="*60)

qualidade_dados(players, "Players")
qualidade_dados(lojas, "Lojas")
qualidade_dados(transacoes, "Transações")
qualidade_dados(pedestres, "Pedestres")
# Out:
# Dataset: Players
# Dimensões: (10000, 11)
#
# Tipos de dados:
# celular                  object
# data_nascimento          object
# idade                     int64
# sexo                     object
# cidade_residencial       object
# bairro_residencial       object
# cidade_trabalho          object
# bairro_trabalho          object
# cidade_escola            object
# bairro_escola            object
# categoria_frequentada    object
# dtype: object
#
# Valores ausentes:
# celular                     0
# data_nascimento             0
# idade                       0
# sexo                        0
# cidade_residencial          0
# bairro_residencial          0
# cidade_trabalho          3969
# bairro_trabalho          3969
# cidade_escola            6932
# bairro_escola            6932
# categoria_frequentada       0
# dtype: int64
#
# Duplicados: 0
# ============================================================
#
# Dataset: Lojas
# Dimensões: (10000, 11)
#
# Tipos de dados:
# numero_celular     object
# data_captura       object
# tipo_cupom         object
# tipo_loja          object
# local_captura      object
# latitude           object
# longitude          object
# nome_loja          object
# endereco_loja      object
# valor_compra      float64
# valor_cupom       float64
# dtype: object
#
# Valores ausentes:
# numero_celular    0
# data_captura      0
# tipo_cupom        0
# tipo_loja         0
# local_captura     0
# latitude          0
# longitude         0
# nome_loja         0
# endereco_loja     0
# valor_compra      0
# valor_cupom       0
# dtype: int64
#
# Duplicados: 0
# ============================================================
#
# Dataset: Transações
# Dimensões: (100000, 12)
#
# Tipos de dados:
# celular                       object
# data                          object
# hora                          object
# nome_estabelecimento          object
# bairro_estabelecimento        object
# categoria_estabelecimento     object
# id_campanha                   object
# id_cupom                      object
# tipo_cupom                    object
# produto                       object
# valor_cupom                  float64
# repasse_picmoney             float64
# dtype: object
#
# Valores ausentes:
# celular                          0
# data                             0
# hora                             0
# nome_estabelecimento             0
# bairro_estabelecimento           0
# categoria_estabelecimento        0
# id_campanha                      0
# id_cupom                         0
# tipo_cupom                       0
# produto                      66672
# valor_cupom                      0
# repasse_picmoney                 0
# dtype: int64
#
# Duplicados: 0
# ============================================================
#
# Dataset: Pedestres
# Dimensões: (100000, 15)
#
# Tipos de dados:
# celular                    object
# data                       object
# horario                    object
# local                      object
# latitude                   object
# longitude                  object
# tipo_celular               object
# modelo_celular             object
# possui_app_picmoney        object
# data_ultima_compra         object
# ultimo_tipo_cupom          object
# ultimo_valor_capturado    float64
# ultimo_tipo_loja           object
# idade                       int64
# sexo                       object
# dtype: object
#
# Valores ausentes:
# celular                       0
# data                          0
# horario                       0
# local                         0
# latitude                      0
# longitude                     0
# tipo_celular                  0
# modelo_celular                0
# possui_app_picmoney           0
# data_ultima_compra        40043
# ultimo_tipo_cupom         40043
# ultimo_valor_capturado    40043
# ultimo_tipo_loja          40043
# idade                         0
# sexo                          0
# dtype: int64
#
# Duplicados: 0
# ============================================================

# %%
# Bloco 4: Tratamento básico dos dados

# Remover possíveis duplicados
players = players.drop_duplicates()
lojas = lojas.drop_duplicates()
transacoes = transacoes.drop_duplicates()
pedestres = pedestres.drop_duplicates()

# Remover possíveis valores ausentes
players = players.dropna()
lojas = lojas.dropna()
transacoes = transacoes.dropna()
pedestres = pedestres.dropna()

# %%
# Bloco 5: Pré-visualização
print("Players:")
display(players.head())

print("Lojas:")
display(lojas.head())

print("Transações:")
display(transacoes.head())

print("Pedestres:")
display(pedestres.head())
# Out:
# Players:
#             celular data_nascimento  idade       sexo cidade_residencial  \
# 17  (11) 96539-1344      03/08/1937     88      Outro          São Paulo
# 22  (11) 98956-8886      13/07/1991     34  Masculino          São Paulo
# 23  (11) 98973-3536      24/01/1971     54  Masculino          São Paulo
# 26  (11) 97484-3144      30/04/2004     21      Outro          São Paulo
# 29  (31) 95333-2891      18/09/1994     30  Masculino          São Paulo
#
#    bairro_residencial cidade_trabalho bairro_trabalho cidade_escola  \
# 17               Lapa       São Paulo      Bela Vista     São Paulo
# 22         Consolação       São Paulo              Sé     São Paulo
# 23         Consolação       São Paulo       República     São Paulo
# 26          Jabaquara       São Paulo         Santana     São Paulo
# 29       Higienópolis       São Paulo      Casa Verde     São Paulo
#
#    bairro_escola                              categoria_frequentada
# 17   Campo Limpo              Supermercados de Bairro e Mercadinhos
# 22         Limão  Lojas de Eletrodomésticos e Utilidades Domésticas
# 23  Higienópolis       Postos de Combustível e Serviços Automotivos
# 26       Santana                      Cafeterias e Bistrôs Modernos
# 29    Casa Verde                 Lojas de Moda Urbana e Alternativa
# Lojas:
#     numero_celular data_captura tipo_cupom  tipo_loja  \
# 0  (41) 96047-8110   05/07/2025    Produto     outros
# 1  (11) 94020-8306   12/07/2025   Desconto     móveis
# 2  (11) 92863-4530   19/07/2025    Produto     móveis
# 3  (11) 94282-1224   19/07/2025    Produto  vestuário
# 4  (11) 91506-1278   05/07/2025    Produto     outros
#
#                local_captura                 latitude  \
# 0          Calçada aleatória  -23.563.850.985.754.000
# 1          Calçada aleatória   -2.356.380.569.343.850
# 2  Shopping Cidade São Paulo  -23.563.227.246.012.400
# 3                   Semáforo   -2.356.152.623.615.530
# 4    Shopping Pátio Paulista   -2.357.068.984.231.570
#
#                  longitude      nome_loja  \
# 0   -4.665.004.147.929.030  Pão de Açúcar
# 1   -4.664.954.309.104.300  Pão de Açúcar
# 2   -4.665.237.324.108.700        Kalunga
# 3   -4.665.376.976.958.120    Daiso Japan
# 4  -46.645.488.231.986.900      Smart Fit
#
#                                       endereco_loja  valor_compra  valor_cupom
# 0                                Rua Pamplona, 1704        834.43        28.21
# 1                                Rua Pamplona, 1704        884.21       398.81
# 2                                 Rua Augusta, 2220        903.79        48.43
# 3  Shopping Pátio Paulista, Rua Treze de Maio, 1947        792.39        10.82
# 4                                Av. Paulista, 2006        146.92         8.34
# Transações:
#            celular        data      hora nome_estabelecimento  \
# 2  (11) 97965-2178  20/07/2025  16:45:00              Outback
# 3  (11) 93418-4646  20/07/2025  15:45:00               Subway
# 4  (11) 97973-1725  07/07/2025  11:00:00         Octavio Café
# 5  (61) 99274-7566  16/07/2025  09:30:00               Madero
# 6  (11) 99900-5956  17/07/2025  08:45:00           Forever 21
#
#   bairro_estabelecimento                      categoria_estabelecimento  \
# 2               Tucuruvi          Igrejas e Lojas de Artigos Religiosos
# 3                  Penha         Fisioterapia e Terapias Complementares
# 4            Santo Amaro                Clínicas Médicas e Laboratórios
# 5              Pinheiros             Lojas de Moda Urbana e Alternativa
# 6                Tatuapé  Espaços Culturais e de Experiência Interativa
#
#   id_campanha   id_cupom tipo_cupom    produto  valor_cupom  repasse_picmoney
# 2     CAM6473  CUP670811    Produto    Tempora       719.06             27.61
# 3     CAM8293  CUP590364    Produto     Magnam       798.34             25.85
# 4     CAM5588  CUP528033    Produto       Quam       718.45             28.85
# 5     CAM6861  CUP623764    Produto   Eligendi       130.70              2.14
# 6     CAM7963  CUP142621    Produto  Excepturi       446.41              5.28
# Pedestres:
#            celular        data   horario                      local  \
# 0  (11) 98549-4373  22/07/2025  07:30:00   Ponto de Ônibus Pamplona
# 3  (11) 94777-4030  22/07/2025  19:00:00           Metrô Consolação
# 4  (21) 91994-3239  22/07/2025  13:00:00         Esquina Rua da Paz
# 6  (11) 94559-2684  22/07/2025  12:15:00                       MASP
# 7  (11) 91185-9749  22/07/2025  08:00:00  Shopping Cidade São Paulo
#
#                   latitude                longitude tipo_celular  \
# 0  -23.567.430.342.750.400   -4.664.844.333.528.140       iPhone
# 3   -2.355.617.081.756.250   -4.666.130.627.469.660      Android
# 4   -2.356.254.630.989.870   -4.664.956.662.319.300       iPhone
# 6  -23.561.531.245.538.800   -4.665.609.027.000.710       iPhone
# 7   -2.356.305.240.568.520  -46.652.317.302.801.800      Android
#
#   modelo_celular possui_app_picmoney data_ultima_compra ultimo_tipo_cupom  \
# 0      iPhone SE                 Sim         22/06/2025          Cashback
# 3   Motorola G60                 Sim         15/07/2025          Desconto
# 4      iPhone 12                 Sim         03/07/2025          Cashback
# 6      iPhone 11                 Sim         18/07/2025           Produto
# 7    Samsung S21                 Sim         06/07/2025          Desconto
#
#    ultimo_valor_capturado ultimo_tipo_loja  idade       sexo
# 0                  215.39  mercado express     70   Feminino
# 3                   42.18           outros     69  Masculino
# 4                  244.34      restaurante     67  Masculino
# 6                  255.58        esportivo     52   Feminino
# 7                   24.55         farmácia     54      Outro

# %%
# Bloco 6: Estatísticas descritivas
print("Descrição - Players")
display(players.describe(include="all").T)

print("Descrição - Lojas")
display(lojas.describe(include="all").T)

print("Descrição - Transações")
display(transacoes.describe(include="all").T)

print("Descrição - Pedestres")
display(pedestres.describe(include="all").T)
# Out:
# Descrição - Players
#                         count unique                    top  freq       mean  \
# celular                  1863   1863        (11) 95040-8919     1        NaN
# data_nascimento          1863   1798             14/11/1991     3        NaN
# idade                  1863.0    NaN                    NaN   NaN  53.119163
# sexo                     1863      3              Masculino   635        NaN
# cidade_residencial       1863    147              São Paulo  1677        NaN
# bairro_residencial       1863     21                Santana   103        NaN
# cidade_trabalho          1863      1              São Paulo  1863        NaN
# bairro_trabalho          1863     21                     Sé   236        NaN
# cidade_escola            1863      1              São Paulo  1863        NaN
# bairro_escola            1863     21           Higienópolis   245        NaN
# categoria_frequentada    1863     29  Farmácias e Drogarias   142        NaN
#
#                              std   min   25%   50%   75%   max
# celular                      NaN   NaN   NaN   NaN   NaN   NaN
# data_nascimento              NaN   NaN   NaN   NaN   NaN   NaN
# idade                  21.292797  16.0  35.0  53.0  71.0  91.0
# sexo                         NaN   NaN   NaN   NaN   NaN   NaN
# cidade_residencial           NaN   NaN   NaN   NaN   NaN   NaN
# bairro_residencial           NaN   NaN   NaN   NaN   NaN   NaN
# cidade_trabalho              NaN   NaN   NaN   NaN   NaN   NaN
# bairro_trabalho              NaN   NaN   NaN   NaN   NaN   NaN
# cidade_escola                NaN   NaN   NaN   NaN   NaN   NaN
# bairro_escola                NaN   NaN   NaN   NaN   NaN   NaN
# categoria_frequentada        NaN   NaN   NaN   NaN   NaN   NaN
# Descrição - Lojas
#                   count unique  \
# numero_celular    10000   9999
# data_captura      10000     31
# tipo_cupom        10000      3
# tipo_loja         10000      8
# local_captura     10000      7
# latitude          10000  10000
# longitude         10000  10000
# nome_loja         10000     15
# endereco_loja     10000     14
# valor_compra    10000.0    NaN
# valor_cupom     10000.0    NaN
#
#                                                              top  freq  \
# numero_celular                                   (11) 98154-1108     2
# data_captura                                          12/07/2025  1261
# tipo_cupom                                              Cashback  3340
# tipo_loja                                              esportivo  1345
# local_captura                                  Calçada aleatória  2503
# latitude                                  -2.356.380.731.240.190     1
# longitude                                -46.649.952.482.413.200     1
# nome_loja                                              Havaianas   709
# endereco_loja   Shopping Pátio Paulista, Rua Treze de Maio, 1947  1297
# valor_compra                                                 NaN   NaN
# valor_cupom                                                  NaN   NaN
#
#                       mean         std     min      25%      50%      75%  \
# numero_celular         NaN         NaN     NaN      NaN      NaN      NaN
# data_captura           NaN         NaN     NaN      NaN      NaN      NaN
# tipo_cupom             NaN         NaN     NaN      NaN      NaN      NaN
# tipo_loja              NaN         NaN     NaN      NaN      NaN      NaN
# local_captura          NaN         NaN     NaN      NaN      NaN      NaN
# latitude               NaN         NaN     NaN      NaN      NaN      NaN
# longitude              NaN         NaN     NaN      NaN      NaN      NaN
# nome_loja              NaN         NaN     NaN      NaN      NaN      NaN
# endereco_loja          NaN         NaN     NaN      NaN      NaN      NaN
# valor_compra    549.684075  260.762003  100.09  323.385  548.885   776.26
# valor_cupom      70.353666   91.065168    1.23  16.1275    32.92  79.8225
#
#                    max
# numero_celular     NaN
# data_captura       NaN
# tipo_cupom         NaN
# tipo_loja          NaN
# local_captura      NaN
# latitude           NaN
# longitude          NaN
# nome_loja          NaN
# endereco_loja      NaN
# valor_compra    999.92
# valor_cupom     492.57
# Descrição - Transações
#                              count unique                    top   freq  \
# celular                      33328   4669        (11) 92941-5524     35
# data                         33328     31             21/07/2025   1145
# hora                         33328     65               16:00:00    564
# nome_estabelecimento         33328     33             Droga Raia   1460
# bairro_estabelecimento       33328     21                Butantã   1655
# categoria_estabelecimento    33328     29  Farmácias e Drogarias   2298
# id_campanha                  33328   8761                CAM2639     14
# id_cupom                     33328  32659              CUP874427      3
# tipo_cupom                   33328      1                Produto  33328
# produto                      33328    182                   Odio    212
# valor_cupom                33328.0    NaN                    NaN    NaN
# repasse_picmoney           33328.0    NaN                    NaN    NaN
#
#                                  mean         std     min       25%     50%  \
# celular                           NaN         NaN     NaN       NaN     NaN
# data                              NaN         NaN     NaN       NaN     NaN
# hora                              NaN         NaN     NaN       NaN     NaN
# nome_estabelecimento              NaN         NaN     NaN       NaN     NaN
# bairro_estabelecimento            NaN         NaN     NaN       NaN     NaN
# categoria_estabelecimento         NaN         NaN     NaN       NaN     NaN
# id_campanha                       NaN         NaN     NaN       NaN     NaN
# id_cupom                          NaN         NaN     NaN       NaN     NaN
# tipo_cupom                        NaN         NaN     NaN       NaN     NaN
# produto                           NaN         NaN     NaN       NaN     NaN
# valor_cupom                548.925761  259.166222  100.07  324.8325  549.35
# repasse_picmoney            19.287155   12.660937    1.07      9.08   16.25
#
#                                 75%     max
# celular                         NaN     NaN
# data                            NaN     NaN
# hora                            NaN     NaN
# nome_estabelecimento            NaN     NaN
# bairro_estabelecimento          NaN     NaN
# categoria_estabelecimento       NaN     NaN
# id_campanha                     NaN     NaN
# id_cupom                        NaN     NaN
# tipo_cupom                      NaN     NaN
# produto                         NaN     NaN
# valor_cupom                771.8925  999.96
# repasse_picmoney               27.4   59.66
# Descrição - Pedestres
#                           count unique                     top   freq  \
# celular                   59957  59939         (11) 93106-1596      2
# data                      59957      1              22/07/2025  59957
# horario                   59957     65                17:30:00   1950
# local                     59957     10        Metrô Consolação   6117
# latitude                  59957  59957  -2.356.323.500.092.910      1
# longitude                 59957  59957  -4.665.240.912.152.810      1
# tipo_celular              59957      2                 Android  41867
# modelo_celular            59957     10              Realme C35   8531
# possui_app_picmoney       59957      1                     Sim  59957
# data_ultima_compra        59957     30              23/06/2025   2057
# ultimo_tipo_cupom         59957      3                 Produto  20219
# ultimo_valor_capturado  59957.0    NaN                     NaN    NaN
# ultimo_tipo_loja          59957      8             restaurante   7604
# idade                   59957.0    NaN                     NaN    NaN
# sexo                      59957      3                Feminino  20031
#
#                               mean         std    min     25%    50%    75%  \
# celular                        NaN         NaN    NaN     NaN    NaN    NaN
# data                           NaN         NaN    NaN     NaN    NaN    NaN
# horario                        NaN         NaN    NaN     NaN    NaN    NaN
# local                          NaN         NaN    NaN     NaN    NaN    NaN
# latitude                       NaN         NaN    NaN     NaN    NaN    NaN
# longitude                      NaN         NaN    NaN     NaN    NaN    NaN
# tipo_celular                   NaN         NaN    NaN     NaN    NaN    NaN
# modelo_celular                 NaN         NaN    NaN     NaN    NaN    NaN
# possui_app_picmoney            NaN         NaN    NaN     NaN    NaN    NaN
# data_ultima_compra             NaN         NaN    NaN     NaN    NaN    NaN
# ultimo_tipo_cupom              NaN         NaN    NaN     NaN    NaN    NaN
# ultimo_valor_capturado  254.791789  141.546678  10.02  132.13  255.3  376.7
# ultimo_tipo_loja               NaN         NaN    NaN     NaN    NaN    NaN
# idade                    42.949681   15.853543   16.0    29.0   43.0   57.0
# sexo                           NaN         NaN    NaN     NaN    NaN    NaN
#
#                            max
# celular                    NaN
# data                       NaN
# horario                    NaN
# local                      NaN
# latitude                   NaN
# longitude                  NaN
# tipo_celular               NaN
# modelo_celular             NaN
# possui_app_picmoney        NaN
# data_ultima_compra         NaN
# ultimo_tipo_cupom          NaN
# ultimo_valor_capturado  499.98
# ultimo_tipo_loja           NaN
# idade                     70.0
# sexo                       NaN

# %%
# Bloco 7: KPIs e análises

# KPI 1: Número de clientes únicos
clientes_totais = players.shape[0]

# KPI 2: Número de lojas parceiras
lojas_unicas = transacoes['nome_estabelecimento'].unique()

# KPI 3: Volume total transacionado
volume_total = lojas["valor_compra"].sum()

# KPI 4: Valor médio dos cupons
valor_medio_cupom = lojas["valor_cupom"].mean()

# KPI 5: Ticket médio por compra
ticket_medio = lojas["valor_compra"].mean()

# KPI 6: Número de pedestres únicos
pedestres_unicos = pedestres.shape[0]


print("📌 KPIs para CEO & CFO")
print(f"Clientes únicos: {clientes_totais}")
print(f"Lojas parceiras: {len(lojas_unicas)}")
print(f"Volume total transacionado: R$ {volume_total:,.2f}")
print(f"Valor médio dos cupons: R$ {valor_medio_cupom:,.2f}")
print(f"Ticket médio: R$ {ticket_medio:,.2f}")
print(f"Pedestres únicos registrados: {pedestres_unicos}")


# Visualizações
fig, axs = plt.subplots(1, 2, figsize=(12,5))

# Distribuição de valores de compra
sns.histplot(lojas["valor_compra"], bins=30, ax=axs[0], kde=True)
axs[0].set_title("Distribuição dos Valores de Compra")

# Relação cupom vs compra
sns.scatterplot(data=lojas.sample(5000), x="valor_cupom", y="valor_compra", alpha=0.5, ax=axs[1])
axs[1].set_title("Cupom vs Valor da Compra")

plt.tight_layout()
plt.show()
# Out:
# 📌 KPIs para CEO & CFO
# Clientes únicos: 1863
# Lojas parceiras: 33
# Volume total transacionado: R$ 5,496,840.75
# Valor médio dos cupons: R$ 70.35
# Ticket médio: R$ 549.68
# Pedestres únicos registrados: 59957
